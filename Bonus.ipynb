# %%
# Importing dependency for pandas
import pandas as pd
import numpy as np

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
# Connect to the DB
conn = psycopg2.connect(
    #host = 'postgres',
    database = 'SQL_HW_DB',
    user = 'postgres',
    password = 'Knicks2019')

cursor = conn.cursor()

#execute query
cursor.execute('SELECT t.title, avg(s.salary) FROM salary s join titles t on s.emp_no = t.emp_no group by t.title')

# Created a variable 'row' in order to pull all rows that fall under the query execute
row = cursor.fetchall()

for r in row:
    print(r)
    #print(dict(r).setdefault())
    #df = pd.DataFrame(r, columns=['Title'])
    #print(df)

    
cursor.close()
# Close the connection
conn.close()

#print(row)
# Out:
# ('Assistant Engineer', Decimal('48493.204785827604'))
# ('Engineer', Decimal('48539.781423093311'))
# ('Manager', Decimal('51531.041666666667'))
# ('Senior Engineer', Decimal('48506.751805626598'))
# ('Senior Staff', Decimal('58503.286614325870'))
# ('Staff', Decimal('58465.271903604585'))
# ('Technique Leader', Decimal('48580.505772148559'))

# %%
df = pd.DataFrame({'Title': ['Assistant Engineer', 'Engineer', 'Manager', 'Senior Engineer', 'Senior Staff', 'Staff', 'Technique Leader'],
                  'Average Salary': [48493, 48540, 51531, 48507, 58503, 58465, 48580]})
new_df = df.set_index('Title')         
new_df
# Out:
#                     Average Salary
# Title
# Assistant Engineer           48493
# Engineer                     48540
# Manager                      51531
# Senior Engineer              48507
# Senior Staff                 58503
# Staff                        58465
# Technique Leader             48580

# %%
new_df.plot(kind="bar")
# Set a title for the chart
plt.title("Average Salary per title")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Import dependency to plot the aove dataframe
import matplotlib.pyplot as plt
